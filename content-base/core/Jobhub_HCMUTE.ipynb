# %% [markdown]
# # Music recommender system
#
# One of the most used machine learning algorithms is recommendation systems. A **recommender** (or recommendation) **system** (or engine) is a filtering system which aim is to predict a rating or preference a user would give to an item, eg. a film, a product, a song, etc.
#
# Which type of recommender can we have?
#
# There are two main types of recommender systems:
# - Content-based filters
# - Collaborative filters
#
# > Content-based filters predicts what a user likes based on what that particular user has liked in the past. On the other hand, collaborative-based filters predict what a user like based on what other users, that are similar to that particular user, have liked.
#
# ### 1) Content-based filters
#
# Recommendations done using content-based recommenders can be seen as a user-specific classification problem. This classifier learns the user's likes and dislikes from the features of the song.
#
# The most straightforward approach is **keyword matching**.
#
# In a few words, the idea behind is to extract meaningful keywords present in a song description a user likes, search for the keywords in other song descriptions to estimate similarities among them, and based on that, recommend those songs to the user.
#
# *How is this performed?*
#
# In our case, because we are working with text and words, **Term Frequency-Inverse Document Frequency (TF-IDF)** can be used for this matching process.
#
# We'll go through the steps for generating a **content-based** music recommender system.

# %% [markdown]
# ### Importing required libraries
#
# First, we'll import all the required libraries.

# %%
import numpy as np
import pandas as pd

# %%
from typing import List, Dict

# %% [markdown]
# We have already used the **TF-IDF score before** when performing Twitter sentiment analysis.
#
# Likewise, we are going to use TfidfVectorizer from the Scikit-learn package again.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Dataset

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'ODBC Driver 17 for SQL Server']

# %% [markdown]
# So imagine that we have the [following dataset](https://www.kaggle.com/mousehead/songlyrics/data#).
#
# This dataset contains name, artist, and lyrics for *57650 songs in English*. The data has been acquired from LyricsFreak through scraping.

# %%
import pyodbc
import csv
import pandas as pd

# Chuỗi kết nối SQL Server
server = 'job-hub-kltn.database.windows.net'
database = 'job-hub-database'
username = 'jobhub'
password = '28072002Thanh'
driver = '{ODBC Driver 17 for SQL Server}'

# Tạo chuỗi kết nối
connection_string = f'DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD={password}'

# Kết nối đến cơ sở dữ liệu
conn = pyodbc.connect(connection_string)

# Tạo một đối tượng cursor để thực thi các truy vấn SQL
cursor = conn.cursor()

# Ví dụ truy vấn SQL
query = """
SELECT * FROM job
"""
cursor.execute(query)

# Lấy tất cả các hàng từ cursor
rows = cursor.fetchall()

# Ghi dữ liệu vào tệp CSV
with open('data_sql.csv', 'w', newline='', encoding='utf-8') as f:
    # Tạo đối tượng ghi CSV
    writer = csv.writer(f)
    
    # Ghi tiêu đề của các cột
    writer.writerow([column[0] for column in cursor.description])
    
    # Ghi dữ liệu từ các hàng
    writer.writerows(rows)

# Đóng kết nối đến cơ sở dữ liệu
conn.close()

# Đọc dữ liệu từ tệp CSV vào DataFrame
job_df = pd.read_csv('data_sql.csv')

# %%
rows
# Out:
# [('00249d9f-88ea-4b81-a0ca-1923a8a75fce', '&lt;p&gt;- Thu nhập:\xa0&lt;/p&gt;&lt;p&gt;- Giáo viên Full time: Lương từ 10-18 Triệu/tháng&lt;/p&gt;&lt;p&gt;- Giáo viên Part time: Lương thỏa thuận&lt;/p&gt;&lt;p&gt;- Ứng viên có thể lựa chọn 1 trong 2 cơ sở để thuận tiện đi lại\xa0&lt;/p&gt;&lt;p&gt;- Mỗi lớp tối đa 8 - 10 học sinh và 1 trợ giảng hỗ trợ\xa0&lt;/p&gt;&lt;p&gt;- Đa số các lớp được cung cấp giáo trình, slide và phiếu bài tập về nhà&lt;/p&gt;&lt;p&gt;- Môi trường làm việc trẻ trung, năng động, tâm huyết với nghề.&lt;/p&gt;&lt;p&gt;- Được sắp xếp nhiều ca dạy để tăng thu nhập&lt;/p&gt;&lt;p&gt;- Được đào tạo góp ý để nâng cao chuyên môn và kỹ năng&lt;/p&gt;&lt;p&gt;- Được ưu đãi học phí cho người thân khi đăng ký học tại trung tâm&lt;/p&gt;&lt;p&gt;- Cơ hội thăng tiến được cân nhắc lên vị trí quản lý&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 45, 36), datetime.datetime(2024, 4, 1, 0, 0), '&lt;p&gt;- Giảng dạy ngữ pháp, kỹ năng đọc viết và quản lý trật tự lớp.&lt;/p&gt;&lt;p&gt;- Giúp học sinh hiểu bài cặn kẽ và nhớ bài\xa0&lt;/p&gt;&lt;p&gt;- Phản hồi với cấp trên về tình hình học tập của lớp mỗi tuần.&lt;/p&gt;', 2, True, 'CONTRACT', 'https://www.topcv.vn/viec-lam/giao-vien-tieng-anh-kinh-nghiem-tu-1-nam-tro-len-thu-nhap-tu-10-den-18-trieu/1248585.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-tnhh-pan-pacific-viet-nam-bef3aa48f5659a72f6b57b35d5caa4b8-65e15f6e1b79e.jpg', 'Giáo Viên Tiếng Anh - Kinh Nghiệm Từ 1 Năm Trở Lên - Thu Nhập Từ 10 Đến 18 Triệu', 8, '&lt;p&gt;- Tốt nghiệp chuyên ngành sư phạm Anh hoặc ngôn ngữ Anh xếp loại Khá trở lên (chấp nhận sinh viên đang chờ bằng)&lt;/p&gt;&lt;p&gt;- &lt;b&gt;Giáo viên Nữ - Độ tuổi từ 20- 25 tuổi&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Trình độ tiếng Anh tương đương IELTS 6.5 trở lên, phát âm chuẩn, nói tiếng Anh lưu loát, vững ngữ pháp.&lt;/p&gt;&lt;p&gt;- Không nói ngọng, nói lắp.&lt;/p&gt;&lt;p&gt;- Ưu tiên ứng viên có ít nhất 1 năm kinh nghiệm đứng lớp (từ 10 học sinh trở lên)&lt;/p&gt;&lt;p&gt;- Nhiệt tình và có đam mê với giáo dục&lt;/p&gt;&lt;p&gt;- Thái độ hợp tác - lắng nghe góp ý, có trách nhiệm trong công việc.&lt;/p&gt;', 'VND:10000000-18000000', 0, '5 hours', None, 'e0f3045c-ae4f-40cf-83ba-d845f3c76364', '2DF30267-DFC8-499D-8C43-FF8E436E8EF9', 0, None),
#  ('00526e4f-c995-4bc8-8d4c-527387dbc113', '&lt;ul&gt;&lt;li&gt;&lt;b&gt;Thu nhập hấp dẫn bao gồm: Cơ bản + Doanh số + Hoa hồng, Thu nhập trung bình từ 10 – 40 triệu/ tháng + hoa hồng tích lũy.&lt;/b&gt;&lt;/li&gt;&lt;li&gt;Chương trình kích cầu lớn nhất năm 2024: Giải đặc biệt tặng 1 chung cư VINHOMES GRANDPARK, Giải nhất là 1 chiếc Ô TÔ CAMRY....&lt;/li&gt;&lt;li&gt;Tham gia BHXH, BHYT, BHTN&lt;br /&gt;&lt;/li&gt;&lt;li&gt;Khám sức khỏe định kỳ hàng năm.&lt;/li&gt;&lt;li&gt;Du lịch, teambuilding, year end party hàng năm.&lt;/li&gt;&lt;li&gt;Hỗ trợ phí gửi xe.&lt;/li&gt;&lt;li&gt;Quà sinh nhật, hiếu, hỉ,.....&lt;/li&gt;&lt;li&gt;Thưởng Kaizen.&lt;/li&gt;&lt;li&gt;Thưởng dự án.&lt;/li&gt;&lt;li&gt;Thưởng cuối năm.&lt;/li&gt;&lt;li&gt;Làm việc trong môi trường năng động, thân thiện, thời gian làm việc linh động.&lt;/li&gt;&lt;li&gt;Được phát triển những kĩ năng kinh doanh trong môi trường quốc tế.&lt;/li&gt;&lt;li&gt;Được tham gia các khoá đào tạo chuyên môn về dịch vụ vận chuyển, logistics&lt;br /&gt;&lt;br /&gt;&lt;/li&gt;&lt;/ul&gt;', datetime.datetime(2024, 3, 15, 23, 43, 53), datetime.datetime(2024, 3, 31, 0, 0), '&lt;ul&gt;&lt;li&gt;Tìm kiếm và tư vấn dịch vụ chuyển phát của công ty đến khách hàng mới.&lt;/li&gt;&lt;li&gt;Thực hiện các báo giá, hợp đồng với khách hàng và trình Trưởng phòng Kinh doanh phê duyệt các kết quả đàm phán&lt;/li&gt;&lt;li&gt;Phối hợp với CSKH, Kế toán trong quá trình chăm sóc, xử lý sự cố, thanh toán công nợ.&lt;/li&gt;&lt;li&gt;Phối hợp với Trưởng nhóm/Giám sát Kinh doanh trong việc xây dựng kế hoạch thực hiện doanh thu cho Team&lt;/li&gt;&lt;li&gt;Thời gian làm việc: Từ thứ 2 đến hết sáng thứ 7 hàng tuần ( 8h00-17h30)&lt;/li&gt;&lt;/ul&gt;', 2, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-sales-logistics-nganh-chuyen-phat-nhanh-thu-nhap-tu-15-trieu-tro-len/1248243.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-co-phan-thuong-mai-va-chuyen-phat-nhanh-noi-bai-netco-5d43fb85500d7.jpg', 'Nhân Viên Kinh Doanh/ Sales Logistics (Ngành Chuyển Phát Nhanh) - Thu Nhập Từ 15 Triệu Trở Lên', 2, '&lt;ul&gt;&lt;li&gt;Trình độ cao đẳng trở lên, chuyên ngành Quản trị kinh doanh, marketing, thương mại, kinh tế...&lt;/li&gt;&lt;li&gt;Có kinh nghiệm từ 6 tháng trở lên trong lĩnh vực vận tải, logistic hoặc 6 tháng kinh nghiệm làm việc khách hàng B2B.&lt;/li&gt;&lt;li&gt;Đam mê và nhiệt huyết, tinh thần cầu tiến.&lt;/li&gt;&lt;li&gt;Có laptop cá nhân&lt;/li&gt;&lt;li&gt;Kỹ năng giao tiếp, thuyết trình, làm việc nhóm, làm việc độc lập.&lt;/li&gt;&lt;/ul&gt;', 'VND:10000000-30000000', 0, '6 hours', None, 'd5abbf18-9ac8-44dc-ba71-5a768d1f3887', 'EBC24826-7EF7-4540-86B3-7CCD11481E21', 0, None),
#  ('016d51fa-ca59-46f3-9dc1-3ca070026424', '&lt;p&gt;- Môi trường làm việc dân chủ, hiện đại, chuyên nghiệp, có cơ hội thăng tiến và ổn định lâu dài.&lt;/p&gt;&lt;p&gt;- Được tăng lương theo lộ trình làm việc.\r\n&lt;/p&gt;&lt;p&gt;- Được hưởng các quyền lợi của người lao động (BHXH, BHYT, ...)\r\n&lt;/p&gt;&lt;p&gt;- Làm việc trong môi trường năng động, với nhiều người trẻ tuổi.\r\n&lt;/p&gt;&lt;p&gt;- Được đi du lịch định kỳ cùng với công ty.\r\n&lt;/p&gt;&lt;p&gt;- Thưởng tháng 13 dành cho nhân viên đủ 12 tháng làm việc.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 41, 26), datetime.datetime(2024, 3, 20, 0, 0), '&lt;p&gt;- Nắm bắt được xu hướng về content.\r\n&lt;/p&gt;&lt;p&gt;- Tra cứu, tìm kiếm thông tin theo yêu cầu.\r\n&lt;/p&gt;&lt;p&gt;- Biên phiên dịch tài liệu khi cần.\r\n&lt;/p&gt;&lt;p&gt;- Các công việc khác theo sự phân công của cấp trên.&lt;/p&gt;&lt;p&gt;- Thời gian làm việc : từ thứ 2 đến thứ 7 ( 9h – 18h), được bao ăn trưa tại công ty&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 2, False, 'CONTRACT', 'https://www.topcv.vn/viec-lam/tro-ly-tieng-trung/683076.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/lvXO83mbqNmKExAW6R1rW5Kx0i4SYwy8_1648807908____54ec3b0a3736e9b7df70ce47e25f7c71.jpg', 'Trợ Lý Tiếng Trung', 9, '&lt;p&gt;- Ưu tiên sinh viên sắp và mới tốt nghiệp\r\n&lt;/p&gt;&lt;p&gt;- Trình độ: Tương đương HSK 4 trở lên&lt;/p&gt;&lt;p&gt;- Giới tính: Nữ&lt;/p&gt;&lt;p&gt;- Đặc biệt chịu được áp lực cao trong công việc\r\n&lt;/p&gt;&lt;p&gt;- Thành thạo: Word, Excel, power point và các phần mềm văn phòng khác\r\n&lt;/p&gt;&lt;p&gt;- Hòa đồng, vui tính, kỹ năng giao tiếp tốt;&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 'VND:10000000-15000000', 0, '7 hours', datetime.datetime(2024, 3, 20, 0, 0, 6, 176000), '99b11b9f-7288-4111-aae0-7e2f407163f9', 'c5606085-3ee9-4e1c-9810-daedf514994a', 0, None),
#  ('018e75b3-dc53-4022-b06b-6beb23198a1a', '&lt;p&gt;&lt;b&gt;- Mức lương: Lương cạnh tranh (lên đến 25tr)\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;- Hỗ trợ ăn trưa tại công ty (có người nấu).\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Được hưởng các chế độ như BHXH, BHYT, BHTN...\r\n&lt;/p&gt;&lt;p&gt;- Nghỉ mát hàng năm, nghỉ lễ + tết theo quy định của Nhà nước.\r\n&lt;/p&gt;&lt;p&gt;- Được làm việc trong môi trường văn phòng chuyên nghiệp, thân thiện...\r\n&lt;/p&gt;&lt;p&gt;- Thời gian làm việc: Từ T2 đến hết sáng T7 hàng tuần.&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 43, 18), datetime.datetime(2024, 4, 14, 0, 0), '&lt;p&gt;- Lập hồ sơ thiết kế, triển khai hồ sơ thiết kế cơ sở, hồ sơ thiết kế kỹ thuật, bổ các công trình dân dụng và công nghiệp...\r\n&lt;/p&gt;&lt;p&gt;- Phối hợp làm việc cùng nhóm dự án, hỗ trợ các công việc liên quan đến kiến trúc.\r\n&lt;/p&gt;&lt;p&gt;- Trao đổi thêm khi phỏng vấn.&lt;/p&gt;', 2, True, 'CONTRACT', 'https://www.topcv.vn/viec-lam/kien-truc-su-luong-tu-15-000-000-tro-len/1263835.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/Ak7V1DNWU5qf2DSr92T98jEge1gGbK7e_1650338176____9fe9399b336ca782dde0552a5e36b392.png', 'Kiến Trúc Sư (Lương Từ 15.000.000 Trở Lên)', 3, '&lt;p&gt;&lt;b&gt;- Chỉ nhận Tốt nghiệp đại học ĐH Kiến trúc, ĐH Xây dựng. \r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Thành thạo các phần mềm như Revit, Auto Cad, MS Office, 3DMax, Scketchup,...\r\n&lt;/p&gt;&lt;p&gt;- Kinh nghiệm từ 3 năm trở lên.&lt;/p&gt;', 'VND:0-15000000', 0, '8 hours', None, 'c88d0cbe-0dd4-44d2-842a-c3497e081ead', '235A69EE-10E0-40E7-B261-4EBA9B5A491E', 0, None),
#  ('01a27fb6-f982-4b67-b0b6-c16a88b2eebb', '&lt;p&gt;- Lương khởi điểm: 10 - 12tr/tháng (thỏa thuận trong phỏng vấn) + thưởng KPI + Tháng lương 13.&lt;/p&gt;&lt;p&gt;- Tăng lương: 12-15 tháng/lần.&lt;br /&gt;- Được hưởng các chế độ bảo hiểm theo quy định.&lt;br /&gt;- Môi trường làm việc trẻ, thân thiện và năng động.&lt;br /&gt;- Được đào tạo, phát triển năng lực để đáp ứng yêu cầu công việc và lộ trình thăng tiến.&lt;br /&gt;- Du lịch: 2 lần/năm.&lt;br /&gt;\xa0&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 44, 53), datetime.datetime(2024, 4, 15, 0, 0), '&lt;p&gt;- Biên soạn, tổng hợp tài liệu, xây dựng chuyên đề theo kế hoạch giảng dạy.&lt;/p&gt;&lt;p&gt;- Trực tiếp đứng lớp giảng dạy:&lt;br /&gt;+ Khối THPT: từ lớp 10 đến lớp 12, luyện thi ĐH&lt;br /&gt;- Các lớp theo nhóm nhỏ từ 3 đến 8 học sinh.&lt;br /&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;', 1, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/giao-vien-toan-thpt/1191349.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-tnhh-tu-van-giai-phap-giao-duc-va-dao-tao-minh-hoang-5f5f37fa84448.jpg', 'Giáo Viên Toán THPT', 4, '&lt;p&gt;- Có chuyên môn vững, kinh nghiệm giảng dạy thực tế (nhóm từ 1 đến 10 học sinh)- Độ tuổi: 22 - 32 tuổi&lt;br /&gt;- Nhiệt tình, tận tâm, có định hướng lâu dài với ngành giáo dục.&lt;br /&gt;- Ưu tiên tốt nghiệp ĐH Sư phạm Hà Nội, ĐH Bách Khoa Hà Nội, ĐH Kinh Tế Quốc Dân, ĐH Y Hà Nội...&lt;br /&gt;\xa0&lt;/p&gt;', 'VND:0-12000000', 0, '6 hours', None, 'b44b8cc4-e962-45c9-8442-77c86db2f2d2', 'CBB96933-92E2-407C-89C7-AABA9279B9ED', 0, None),
#  ('01e4342c-d424-4123-9410-61f303ddf11c', '&lt;ul&gt;&lt;li&gt;Thu nhập từ 10.000.000 - 20.000.000vnđ&lt;/li&gt;&lt;li&gt;Nhân viên được tham gia đầy đủ bảo hiểm xã hội theo quy định nhà nước&lt;/li&gt;&lt;li&gt;Được tham gia các khóa đào tạo chuyên môn nâng cao bên ngoài phù hợp theo từng thời điểm.&lt;/li&gt;&lt;li&gt;Nhân viên được hưởng các phúc lợi đặc quyền của THT: chi phí các khóa học bên ngoài, tiệc sinh nhật, phúc lợi cho người thân, hoạt động thể thao, teambuilding, các hội nhóm học tập trong công ty,...&lt;/li&gt;&lt;li&gt;Nhân viên được cung cấp đầy đủ trang thiết bị để phục vụ công việc&lt;/li&gt;&lt;li&gt;Xét tăng lương hàng năm và các khoản thưởng lễ, quý, sự kiện liên tục trong công ty&lt;/li&gt;&lt;li&gt;Có lộ trình phát triển cho từng nhân viên.&lt;/li&gt;&lt;/ul&gt;', datetime.datetime(2024, 3, 15, 23, 43, 20), datetime.datetime(2024, 4, 30, 0, 0), '&lt;ul&gt;&lt;li&gt;Tiếp nhận, theo dõi, kiểm tra chứng từ liên quan&lt;/li&gt;&lt;li&gt;Tiến hành làm thủ tục Hải quan, CO, báo cáo quyết toán, kiểm tra chuyên ngành về các thủ tục XNK&lt;/li&gt;&lt;li&gt;Sắp xếp với điều phối xe để thực hiện việc lấy hàng, giao hàng phù hợp đúng tiến độ&lt;/li&gt;&lt;li&gt;Thực hiện mở file lô hàng trên phần mềm.&lt;/li&gt;&lt;li&gt;Tư vấn, hỗ trợ khách hàng mới theo như yêu cầu của sales.&lt;/li&gt;&lt;li&gt;Thực hiện việc cập nhật, gửi các thông tư, nghị định, công văn mới liên quan đến xuất nhập khẩu cho khách hàng.&lt;/li&gt;&lt;li&gt;Báo cáo quản lý bộ phận hoặc ban giám đốc các vấn đề liên quan đến lô hàng hoặc khách hàng cần được giải quyết.&lt;/li&gt;&lt;li&gt;Tạo mối quan hệ tốt với các khách hàng đang làm việc để tăng lượng hàng.&lt;/li&gt;&lt;/ul&gt;', 4, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-chung-tu-khai-quan-yc-2-nam-kinh-nghiem/1257706.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/qpi8WsjL4hRkdeT11cNaU9QveM6ZR2iu_1710382196____45f4a3a542c1ede4b6bbd0fd77ed128d.png', 'Nhân Viên Chứng Từ Khai Quan - Yc 2 Năm Kinh Nghiệm', 6, '&lt;ul&gt;&lt;li&gt;&lt;strong&gt;&lt;u&gt;Có kinh nghiệm từ 2 năm làm hàng KCN, các loại hình SXXK, gia công, chế xuất&lt;/u&gt;&lt;/strong&gt;&lt;/li&gt;&lt;li&gt;Trình độ đại học, cao đẳng chuyên ngành xuất nhập khẩu&lt;/li&gt;&lt;li&gt;Có bằng, chứng chỉ tiếng anh. (Ưu tiên Toiec từ 650 hoặc Ielts 6 chấm)&lt;/li&gt;&lt;li&gt;Có khả năng giao tiếp tốt, chịu học hỏi&lt;/li&gt;&lt;li&gt;Trình độ vi tính văn phòng&lt;/li&gt;&lt;li&gt;Hòa đồng, tinh thần trách nhiệm cao&lt;/li&gt;&lt;li&gt;Có khả năng chịu áp lực công việc tốt&lt;/li&gt;&lt;/ul&gt;', 'VND:10000000-20000000', 0, '8 hours', None, 'be8ffa6b-e6f1-4c02-b8a3-b7af6c15f8c2', '407072D0-85C3-415D-A1A7-C6E321725E89', 0, None),
#  ('0207b0f2-6bf5-44cb-b6dc-abb0b04f516e', '&lt;p&gt;&lt;span&gt;- Chỉ cần bạn có ý chí chúng tôi sẽ đào tạo để bạn phát triển bản thân theo hướng tốt nhất.&lt;/span&gt;&lt;br /&gt;&lt;/p&gt;&lt;p&gt;- Cấp Quản lý dễ thương, gần gũi với nhân viên, sẽ cầm tay chỉ việc cho đến khi thành thạo và hỗ trợ hết mình.&lt;/p&gt;&lt;p&gt;&lt;b&gt;- Lương cơ bản: Từ 6tr đến 15tr/tháng.&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;+ Hỗ trợ marketing.&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;+ Hoa hồng bán hàng: Từ 50tr/sản phẩm.&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;+ Thưởng nóng theo từng dự án từ 10tr - 20tr/sản phẩm.&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;+ Thưởng theo từng chiến dịch bán hàng.&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;+ Thưởng cuối năm, du lịch, đóng bảo hiểm, phụ cấp, ...&lt;/b&gt;&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 45, 13), datetime.datetime(2024, 4, 11, 0, 0), '&lt;p&gt;&lt;span&gt;- Triển khai kế hoạch kinh doanh cá nhân dựa trên mục tiêu chung.&lt;/span&gt;&lt;br /&gt;&lt;/p&gt;&lt;p&gt;- Giới thiệu, hướng dẫn khách hàng tham quan dự án, nhà mẫu.&lt;/p&gt;&lt;p&gt;- Tìm kiếm khách hàng mới, mở rộng nguồn khách hàng thông qua các kênh: marketing online (Facebook, zalo, google,...), đăng tin, sale phone, ....\xa0&lt;/p&gt;&lt;p&gt;- Hổ trợ khách hàng các chính sách mua bán, ký hợp đồng, sang nhượng...&lt;/p&gt;&lt;p&gt;- Hỗ trợ khách hàng trong quá trình ký hợp đồng, chăm sóc khách hàng trước và sau bán hàng.&lt;/p&gt;&lt;p&gt;- Cập nhật thông tin thị trường bất động sản, nhanh chóng nắm bắt nhu cầu của khách hàng.&lt;/p&gt;&lt;p&gt;- Tham gia các buổi huấn luyện sản phẩm, học hỏi và chia sẻ kinh nghiệm bán hàng.&lt;/p&gt;&lt;p&gt;- Báo cáo tình hình kinh doanh trực tiếp cho cấp trên.&lt;/p&gt;', 1, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-luong-cung-den-15-trieu-thang-hoa-hong-50tr-san-pham-ho-tro-100-data-khach/1259635.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/2b5ed90a027160c98174b436417a3401-62b9254934f7e.jpg', 'Nhân Viên Kinh Doanh - Lương Cứng Đến 15 Triệu/Tháng + Hoa Hồng 50tr/Sản Phẩm + Hỗ Trợ 100% Data Khách', 3, '&lt;p&gt;&lt;span&gt;- Độ tuổi: Từ 22 đến 32.&lt;/span&gt;&lt;br /&gt;&lt;/p&gt;&lt;p&gt;- Không yêu cầu kinh nghiệm, chúng tôi sẽ hỗ trợ đào tạo bạn.&lt;/p&gt;&lt;p&gt;- Có niềm đam mê kiếm tiền, yêu thích công việc tư vấn bán hàng, gặp gỡ Khách hàng, tinh thần cầu tiến phát triển bản thân.m.&lt;/p&gt;&lt;p&gt;- Có phương tiện đi lại, laptop, smartphone.&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;', 'VND:15000000-50000000', 0, '5 hours', None, '562c2c3d-4b67-48d8-ab1f-a383734a9db3', '0CABFB66-08D0-4875-B8D0-D354FAD825A6', 0, None),
#  ('020a89d1-f2fc-4104-87bf-ed3b67a2179f', '&lt;ul&gt;&lt;li&gt;Dấu xác nhận thực tập&lt;/li&gt;&lt;li&gt;Điện thoại công ty + Hỗ trợ SIM&lt;br /&gt;&lt;/li&gt;&lt;li&gt;Làm việc trong môi trường chuyên nghiệp, năng động, có nhiều cơ hội thăng tiến và phát triển&lt;br /&gt;&lt;/li&gt;&lt;li&gt;Kinh nghiệm làm việc Trẻ trung, Năng động\r\n&lt;/li&gt;&lt;li&gt;Các quyền lợi khác theo luật lao động.&lt;/li&gt;&lt;/ul&gt;', datetime.datetime(2024, 3, 15, 23, 42, 24), datetime.datetime(2024, 4, 7, 0, 0), '&lt;ul&gt;&lt;li&gt;Tìm kiếm và thu thập thông tin trực tiếp về khách hàng tiềm năng (Trong nước/Toàn cầu) (Không sử dụng facebook).\r\n&lt;/li&gt;&lt;li&gt;Tổ chức hoạt động bán sản phẩm trực tiếp tới khách hàng;\r\n&lt;/li&gt;&lt;li&gt;Tìm kiếm khách hàng mới và mở rộng địa điểm tiềm năng.\r\n&lt;/li&gt;&lt;li&gt;Yêu cầu làm việc tại văn phòng và bán hàng tại thị trường.\r\n&lt;/li&gt;&lt;li&gt;Nghiên cứu về ngành công nghiệp chế biến thực phẩm\r\n&lt;/li&gt;&lt;li&gt;Có thể đi công tác xa\r\n&lt;/li&gt;&lt;li&gt;Thực tập sinh toàn thời gian&lt;/li&gt;&lt;/ul&gt;', 5, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/thuc-tap-sinh-sales-marketing-lam-viec-lau-dai-khong-yeu-cau-kinh-nghiem-quan-7/1255605.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/KuoDq3VU6zM0xYcJJKhZA7fgLG7eF1B2_1690769177____208f69445418c1f5ab70bc85129c45f4.png', 'Thực Tập Sinh Sales Marketing (Làm Việc Lâu Dài) - Không Yêu Cầu Kinh Nghiệm - Quận 7', 7, '&lt;ul&gt;&lt;li&gt;Tiếng Anh được ưu tiên\r\n&lt;/li&gt;&lt;li&gt;Chịu được áp lực công việc cao, tinh thần trách nhiệm cao, mục tiêu và kế hoạch làm việc rõ ràng.\r\n&lt;/li&gt;&lt;li&gt;Kỹ năng giao tiếp, đàm phán, thuyết phục tốt.\r\n&lt;/li&gt;&lt;li&gt;Kỹ năng phán đoán và ra quyết định nhanh chóng và dứt khoát, quản lý thời gian\r\n&lt;/li&gt;&lt;li&gt;Học hỏi nhanh, thái độ sẵn sàng, cẩn thận\r\n&lt;/li&gt;&lt;li&gt;Trình độ chuyên môn tốt nghiệp các chuyên ngành : Quản trị/ Quản trị kinh doanh/ Logistics/ Chuỗi cung ứng, Marketing,... các lĩnh vực liên quan khác&lt;br /&gt;&lt;/li&gt;&lt;/ul&gt;', 'VND:0-4000000', 0, '7 hours', None, 'f18e4bbd-7202-4779-a615-f8c0ccaec795', 'CBB96933-92E2-407C-89C7-AABA9279B9ED', 0, None),
#  ('0236ef81-9138-4eaa-8b0f-c99c1b11fff6', '&lt;p&gt;- Lương: Từ 20- 30tr + phụ cấp + hưởng đầy đủ các chế độ khác theo yêu cầu của Luật Lao động&lt;/p&gt;&lt;p&gt;- Thời gian làm việc: Từ thứ 2 đến hết sáng\xa0 thứ 7&lt;br /&gt;\xa0 \xa0T2-T6 : 8h 30 - 17h 30, nghỉ trưa từ 12h-13h, T7: 8h -12h&lt;/p&gt;&lt;p&gt;- Môi trường trẻ trung, năng động, thân thiện, du lịch thường xuyên.&lt;/p&gt;&lt;p&gt;- Sếp dễ tính, dễ chia sẻ\xa0&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 45, 51), datetime.datetime(2024, 4, 4, 0, 0), '&lt;p&gt;- Tổ chức bộ máy kế toán phù hợp với quy mô và mô hình hoạt động của Công ty;&lt;/p&gt;&lt;p&gt;- Kiểm soát doanh thu, chi phí, đánh giá hiệu quả hoạt động sản xuất kinh doanh;&lt;/p&gt;&lt;p&gt;- Lập và phân tích BCTC theo yêu cầu, phân tích quản trị theo yêu cầu.&lt;/p&gt;&lt;p&gt;- Thực hiện các hoạt động Kiểm toán, Quyết toán định kỳ theo quy định.&lt;/p&gt;&lt;p&gt;- Xây dựng kế hoạch tài chính và tổ chức thực hiện, đảm bảo cân đối và sử dụng nguồn vốn hiệu quả.&lt;/p&gt;&lt;p&gt;- Làm việc với các cơ quan liên quan: thuế, kiểm toán.\xa0&lt;/p&gt;&lt;p&gt;- Nộp đầy đủ các báo cáo, các chi phí theo quy định.&lt;/p&gt;&lt;p&gt;- Tổ chức lưu trữ tài liệu theo đúng quy định.&lt;/p&gt;&lt;p&gt;- Xây dựng quy chế, quy trình, quy định, văn bản hướng dẫn thuộc lĩnh vực Kế toán tài chính phù hợp với chức năng, nhiệm vụ được giao và tổ chức thực hiện.&lt;/p&gt;&lt;p&gt;- Thực hiện theo các yêu cầu khác do Giám đốc giao.&lt;/p&gt;', 2, True, 'CONTRACT', 'https://www.topcv.vn/viec-lam/ke-toan-truong-thu-nhap-tu-20-30-trieu/1251244.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-tnhh-thuong-mai-va-phan-phoi-toan-cau-hth-335a9c274409ac2b4962544c48cb09ce-65e677b92c79c.jpg', 'Kế Toán Trưởng Thu Nhập Từ 20 - 30 Triệu', 2, '&lt;p&gt;- Tốt nghiệp Đại học chuyên ngành Tài chính – Kế toán.&lt;/p&gt;&lt;p&gt;&lt;b&gt;- Có kinh nghiệm trong lĩnh vực nhập khẩu hàng tiêu dùng và bán lẻ&lt;/b&gt;&lt;/p&gt;&lt;p&gt; &lt;/p&gt;&lt;p&gt;- Tối thiểu 5 năm kinh nghiệm ở vị trí tương đương hoặc 3 năm nhưng đã có kinh nghiệm về quyết toán thuế.&lt;/p&gt;&lt;p&gt;- Nắm vững các quy định, chuẩn mực kế toán và các quy định, chính sách về thuế.&lt;/p&gt;&lt;p&gt;- Nắm vững các nguyên tắc và tiền lệ được áp dụng để giải quyết các vấn đề kế toán, thuế.&lt;/p&gt;&lt;p&gt;- Hiểu biết rõ các nguyên tắc về tổ chức, quản lý và có kiến thức vững về kinh tế, tài chính, ngân hàng.&lt;/p&gt;&lt;p&gt;- Tuân thủ đạo đức nghề nghiệp, tư cách tốt, cẩn thận, chăm chỉ, có tinh thần cầu tiến trong công việc.&lt;/p&gt;&lt;p&gt;- Ưu tiên ứng viên đã làm tại các Công ty thương mại&lt;/p&gt;&lt;p&gt;- Ưu tiên ứng viên Có gia đình ổn định, có dự định gắn bó lâu dài.&lt;/p&gt;', 'VND:20000000-30000000', 0, '8 hours', None, '190843b7-28d6-4f0f-9d80-996a416681ab', 'D5846B71-9143-4458-8DCE-1FFCD49AB3C2', 0, None),
#  ('023f65d6-b045-4c3c-a4d4-14d95c47d913', '&lt;p&gt;&lt;b&gt;- Lương: 18 - 22 triệu /tháng + PC.\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Địa điểm làm việc: Văn phòng công ty Aladdin – Tòa nhà GTC Galaxy 69 Tố Hữu, Vạn Phúc, Hà Đông.\r\n&lt;/p&gt;&lt;p&gt;- Làm việc tại Công ty hoạt động trong ngành F&amp;B có 2 thương hiệu Bò tơ quán mộc và Longwang.\r\n&lt;/p&gt;&lt;p&gt;- Thời gian làm việc: Giờ hành chính (Nghỉ chiều thứ 7 + CN).\r\n&lt;/p&gt;&lt;p&gt;- Chế độ khen thưởng, phúc lợi: Tham gia BHXH đầy đủ; chính sách khen thưởng hàng tháng, năm; lương tháng 13++++ theo kết quả kinh doanh của công ty; thưởng nhân các ngày lễ/tết trong năm; nghỉ dưỡng định kỳ.\r\n&lt;/p&gt;&lt;p&gt;- Lương và cơ hội thăng tiến: Hàng năm công ty xem xét và điều chỉnh tăng lương theo kết quả công việc; đối với những cá nhân có tiềm năng có cơ hội tham gia các dự án của của công ty, xây dưng quy hoạch cán bộ nguồn và có nhiều cơ hội thăng tiến.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 45, 10), datetime.datetime(2024, 4, 11, 0, 0), '&lt;p&gt;- Nghiên cứu các ứng dụng Quản trị, vận hành doanh nghiệp\r\n&lt;/p&gt;&lt;p&gt;- Nghiên cứu Hệ thống vận hành F&amp;B\r\n&lt;/p&gt;&lt;p&gt;- Đề xuất lựa chọn giải pháp Công nghệ\r\n&lt;/p&gt;&lt;p&gt;- Khảo sát yêu cầu: Phân tích yêu cầu, phân tích Gaps\r\n&lt;/p&gt;&lt;p&gt;- Phân tích thiết kế: Giải pháp đáp ứng; Quy trình tương lai; Kịch bản kiểm thử\r\n&lt;/p&gt;&lt;p&gt;- Xây dựng phần mềm và Kiểm thử nội bộ\r\n&lt;/p&gt;&lt;p&gt;- Kiểm thử phần mềm: xây dựng kịch bản kiểm thử và Unit test\r\n&lt;/p&gt;&lt;p&gt;- Quản lý các version thay đổi phần mềm\r\n&lt;/p&gt;&lt;p&gt;- Chuyển giao và nghiệm thu phần mềm\r\n&lt;/p&gt;&lt;p&gt;- Bảo trì, sửa chữa và nâng cấp phần mềm\r\n&lt;/p&gt;&lt;p&gt;- Hỗ trợ đào tạo người dùng sử dụng phần mềm\r\n&lt;/p&gt;&lt;p&gt;- Thực hiện các công việc, hỗ trợ các công việc khác theo yêu cầu của Trưởng phòng và Ban Giám đốc&lt;/p&gt;', 5, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/lap-trinh-vien-mobile-flutter-18-22m-thang-tai-ha-dong-ha-noi/1259369.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-co-phan-tam-nhin-quoc-te-aladdin-613f00ea1cee0.jpg', 'Lập Trình Viên Mobile Flutter (18-22M/ Tháng) Tại Hà Đông , Hà Nội', 3, '&lt;p&gt;- Tốt nghiệp đại học, cao đẳng chuyên ngành CNTT các trường đại học đào tạo chuyên ngành\r\n&lt;/p&gt;&lt;p&gt;- Yêu cầu về kinh nghiệm / thâm niên công tác \r\n&lt;/p&gt;&lt;p&gt;-\xa0 Tối thiểu 6 tháng kinh nghiệm tại vị trí tương đương tại các Doanh nghiệp&lt;/p&gt;&lt;p&gt;- Độ tuổi: 22-35T\r\n&lt;/p&gt;&lt;p&gt;- Tính cách:  trung thực, kiên trì, nhiệt huyết, có tinh thần trách nhiệm, cầu tiến, yêu thương và hỗ trợ đồng đội, năng lượng tích cực.\r\n&lt;/p&gt;&lt;p&gt;- Khả năng làm việc độc lập và theo nhóm.\r\n&lt;/p&gt;&lt;p&gt;- Sáng tạo, ham học hỏi, có trách nhiệm và khát vọng thăng tiến trong công việc.&lt;/p&gt;', 'VND:18000000-22000000', 0, '6 hours', None, '4e221e28-e94e-49ec-82ed-51c3ce4fa800', '20700B5E-5F34-4C5F-B0E5-05AAAE2044D3', 0, None),
#  ('0311827c-fd10-4145-b5e1-a45932780729', '&lt;ul&gt;&lt;li&gt;Môi trường làm việc năng động, thân thiện, trẻ trung&lt;/li&gt;&lt;li&gt;Có mức thu nhập hấp dẫn&lt;/li&gt;&lt;li&gt;Có cơ hội tham gia các hoạt động đào tạo nâng cao trình độ&lt;/li&gt;&lt;li&gt;Hưởng chế độ chăm sóc sức khỏe đặc biệt dành cho bản thân và gia đình (FPT Care)&lt;/li&gt;&lt;li&gt;Được đóng BHXH, BHYT, BHTN... theo quy định của Nhà nước&lt;/li&gt;&lt;li&gt;Người nhà được hưởng chế độ ưu đãi học phí khi học tập tại Tổ chức Giáo dục\xa0FPT&lt;/li&gt;&lt;li&gt;Các quyền lợi khác: du lịch nghỉ mát hàng năm, tham gia các hoạt động vui chơi giải trí...&lt;/li&gt;&lt;li&gt;Làm việc từ thứ 2 đến thứ 6 tại Hòa Lạc, có xe đưa đón&lt;/li&gt;&lt;/ul&gt;', datetime.datetime(2024, 3, 15, 23, 46, 12), datetime.datetime(2024, 4, 13, 0, 0), '&lt;ul&gt;&lt;li&gt;Xây dựng kế hoạch truyền thông và quảng bá thương hiệu nhà tuyển dụng (Employer Branding) trên các kênh online &amp; offline cho Tổ chức Giáo dục FPT&lt;/li&gt;&lt;li&gt;Triển khai các chương trình, hoạt động marketing thu hút ứng viên theo yêu cầu tuyển dụng ngắn và trung hạn&lt;/li&gt;&lt;li&gt;Tham gia sáng tạo &amp; thực hiện content bao gồm: chuỗi video, tin bài chuẩn SEO, hình ảnh trên các kênh social, website&lt;/li&gt;&lt;li&gt;Chịu trách nhiệm về hoạt động marketing tuyển dụng bao gồm tự chạy quảng cáo trên các kênh FB Ads/ Google Ads hoặc phối hợp với agency để đạt KPI của bộ phận&lt;/li&gt;&lt;li&gt;Lên ý tưởng, trực tiếp thực hiện hoặc phối hợp với Agency làm các ấn phẩm tuyển dụng, các banner, background trên website/FP&lt;/li&gt;&lt;li&gt;Quản lý website, FP và các kênh social khác của phòng tuyển dụng&lt;/li&gt;&lt;li&gt;Thực hiện các công việc khác theo phân công từ cấp trên&lt;/li&gt;&lt;/ul&gt;', 4, True, 'PART_TIME', 'https://www.topcv.vn/brand/fptedu/tuyen-dung/can-bo-truyen-thong-tuyen-dung-tai-ha-noi-thu-nhap-hap-dan-j1242651.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/69iEFNHI0d8edsYdTDgV.jpg', 'Cán Bộ Truyền Thông Tuyển Dụng - Tại Hà Nội - Thu Nhập Hấp Dẫn', 6, '&lt;ul&gt;&lt;li&gt;Tốt nghiệp đại học\xa0trở lên, ưu tiên chuyên ngành MKT – Truyền thông, Báo chí, Quản trị nhân lực, QTKD&lt;/li&gt;&lt;li&gt;1-2 năm kinh nghiệm triển khai các dự án thương hiệu Tuyển dụng hoặc 3 năm kinh nghiệm trong lĩnh vực truyền thông và marketing&lt;/li&gt;&lt;li&gt;Có năng lực &amp; kinh nghiệm xây dựng social content theo định hướng&lt;/li&gt;&lt;li&gt;Có kinh nghiệm về digital marketing và SEO, Google Analytics, am hiểu về xây dựng &amp; vận hành website&lt;/li&gt;&lt;li&gt;Có kinh nghiệm lập kế hoạch, triển khai, điều phối sự kiện quy mô tầm trung trở lên&lt;/li&gt;&lt;li&gt;Có khả năng quay &amp; dựng video và thiết kế cơ bản&lt;/li&gt;&lt;li&gt;Tiếng Anh giao tiếp&lt;/li&gt;&lt;li&gt;Gu thẩm mĩ tốt&lt;/li&gt;&lt;/ul&gt;', 'VND:0-20000000', 0, '7 hours', datetime.datetime(2024, 3, 19, 19, 33, 5, 897000), '822771ce-25bf-4509-90e1-660b84c32541', '06FF8A9B-71F5-4CFC-A71F-72020484B955', 1, None),
#  ('031fc728-789a-4c73-a110-88ae8cc91ae1', '&lt;p&gt;&lt;b&gt;• Lương thưởng hấp dẫn, Lương cứng 8tr- 15tr + thưởng; thu nhập 13-19 triệu/tháng.&lt;/b&gt;&lt;/p&gt;&lt;p&gt;• Được hưởng đầy đủ các chế độ đãi ngộ theo Luật Lao động (BHXH, BHYT...);\r\n&lt;/p&gt;&lt;p&gt;• Môi trường làm việc trẻ trung, thân thiện và năng động, sáng tạo;\r\n&lt;/p&gt;&lt;p&gt;• Được hỗ trợ định hướng công việc và lộ trình nghề nghiệp và lộ trình phát triển bản thân rõ ràng;\r\n&lt;/p&gt;&lt;p&gt;• Được xét duyệt tăng lương định kỳ &amp; thưởng cuối năm theo kết quả công việc;\r\n&lt;/p&gt;&lt;p&gt;• Được tham gia tổ chức sinh nhật, du lịch hàng năm;\r\n&lt;/p&gt;&lt;p&gt;• Thưởng lễ, Tết, Lương tháng 13, các chế độ đãi ngộ.\r\n&lt;/p&gt;&lt;p&gt;• Thời gian làm việc: Thứ 2- Thứ 7&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 40, 40), datetime.datetime(2024, 4, 11, 0, 0), '&lt;p&gt;• Trực tiếp  lên kịch bản, chịu trách nhiệm NỘI DUNG cho các kênh Facebook , Tik tok\r\n&lt;/p&gt;&lt;p&gt;• Nội dung ảnh / video / ấn phẩm cho các chiến dịch quảng cáo; hoặc các chương trình, sự kiện của Công ty.\r\n&lt;/p&gt;&lt;p&gt;• Phối hợp với nhân viên quay dựng trong quá trình sản xuất VIDEO phục vụ hoạt động marketing cho các kênh Social: Tiktok, Facebook... (VIDEO ngắn là chính).\r\n&lt;/p&gt;&lt;p&gt;• Đề xuất các giải pháp, sáng kiến về Content, phát triển kênh social, các chiến dịch Marketing, quảng cáo nhằm mang lại hiệu quả cao về thu hút khách hàng, tăng nhận diện thương hiệu...\r\n&lt;/p&gt;&lt;p&gt;• Thực hiện các công việc khác theo sự chỉ đạo của cấp trên.\r\n&lt;/p&gt;&lt;p&gt;• Có khả năng livestream, sẽ tăng thêm chiết khấu\xa0&lt;/p&gt;', 1, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-content-marketing-bien-kich-sang-tao-noi-dung-thu-nhap-upto-19-trieu/1259280.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/U2N0vLjGeF3uWYJ6tQ5vjl0O3hZdA3bY_1646214427____ce543356f5014534ba9bd64e9d059066.png', 'Nhân Viên Content Marketing/ Biên Kịch Sáng Tạo Nội Dung ( Thu Nhập Upto 19 Triệu )', 3, '&lt;p&gt;• Cao đẳng, ĐH: Quản trị kinh doanh, báo chí, marketing, thiết kế... hoặc học ngành bất kỳ\r\n&lt;/p&gt;&lt;p&gt;&lt;b&gt;• Có từ 1 năm kinh nghiệm ở vị trí tương đương. Có kinh nghiệm trong ngành thẩm mỹ là 1 lợi thế\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;• Khả năng sáng tạo nội dung, dàn dựng kịch bản\r\n&lt;/p&gt;&lt;p&gt;• Nắm bắt xu hướng mạng xã hội và sở thích giới trẻ\r\n&lt;/p&gt;&lt;p&gt;• Kỹ năng tìm kiếm khai thác thông tin trên internet, mạng xã hội\r\n&lt;/p&gt;&lt;p&gt;• Kỹ năng lập kế hoạch, phân tích, báo cáo\r\n&lt;/p&gt;&lt;p&gt;• Ham học hỏi, tỉ mỉ, chủ động trong công việc&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 'VND:13000000-19000000', 0, '5 hours', None, '1775a011-3e9d-4fe1-bbd9-c14485749a30', 'E93F133B-8B6F-45C1-9A32-C23D26676224', 0, None),
#  ('03285919-2bb4-4ff5-8dbd-7a90d137a280', '&lt;ul&gt;&lt;li&gt;&lt;b&gt;LƯƠNG CỨNG:  6.000.000 - 8.000.000 VNĐ/tháng (KHÔNG ẢNH HƯỞNG KPI) + THƯỞNG DOANH THU =&gt; THU NHẬP TỪ 15.000.000 - 20.000.000VNĐ/tháng.\r\n&lt;/b&gt;&lt;/li&gt;&lt;li&gt;&lt;b&gt;PHỤ CẤP ĂN CA: 600.000 VNĐ/tháng.\r\n&lt;/b&gt;&lt;/li&gt;&lt;li&gt;&lt;b&gt;CHẾ ĐỘ TĂNG LƯƠNG ĐỊNH KỲ theo chính sách của trung tâm và mức độ hoàn thành công việc theo KPI.\r\n&lt;/b&gt;&lt;/li&gt;&lt;li&gt;Được hưởng các chính sách BHXH, BHYT...\r\n&lt;/li&gt;&lt;li&gt;Hưởng chế độ du lịch, nghỉ mát hàng năm.\r\n&lt;/li&gt;&lt;li&gt;Chế độ lương tháng thứ 13, thưởng theo các ngày lễ tết trong năm.\r\n&lt;/li&gt;&lt;li&gt;Được làm việc môi trường chuyên nghiệp, sáng tạo, cạnh tranh, phát triển, năng động có nhiều cơ hội thăng tiến.&lt;/li&gt;&lt;/ul&gt;', datetime.datetime(2024, 3, 15, 23, 45, 16), datetime.datetime(2024, 4, 6, 0, 0), '&lt;ul&gt;&lt;li&gt;Giới thiệu, tư vấn, chia sẻ, giải thích cho khách hàng về nội dung các khóa học.\r\n&lt;/li&gt;&lt;li&gt;Tiếp nhận thủ tục nhập học của học sinh mới, đảm bảo danh sách học sinh mới, đảm bảo danh sách học sinh được cập nhật đầy đủ cùng hồ sơ học sinh để bàn giao đúng hạn. \r\n&lt;/li&gt;&lt;li&gt;Xây dựng niềm tin với khách hàng bằng việc chăm sóc và hỗ trợ học viên hiện tại nhằm gia tăng số lượng học viên mới thông qua kênh giới thiệu.\r\n&lt;/li&gt;&lt;li&gt;Tiếp nhận, lắng nghe, xử lý các phản hồi từ phía khách hàng thông qua liên lạc điện thoại, chat, mail.\r\n&lt;/li&gt;&lt;li&gt;Check báo cáo đào tạo để giải quyết các bàn giao từ giáo viên.\r\n&lt;/li&gt;&lt;li&gt;Rà soát, kiểm tra việc Post và update các nội dung CSKH trên web- page- group- zalo-email.\r\n&lt;/li&gt;&lt;li&gt;Phối hợp với các bộ phận liên quan thực hiện các sự kiện của trung tâm hoặc hệ thống tổ chức.&lt;/li&gt;&lt;/ul&gt;', 4, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-tu-van-tuyen-sinh-thu-nhap-15-20-trieu/1253471.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-tnhh-solid-viet-nam-5d5979a5b187d0ed21a3f79480766759-65a34cf8e3a1e.jpg', 'Nhân Viên Tư Vấn Tuyển Sinh (Thu Nhập 15 - 20 Triệu)', 2, '&lt;ul&gt;&lt;li&gt;&lt;b&gt;Tốt nghiệp cao đẳng hoặc đại học (Chấp nhận chờ bằng).\r\n&lt;/b&gt;&lt;/li&gt;&lt;li&gt;&lt;b&gt;Nam/nữ, sinh năm từ 1993 - 2000\r\n&lt;/b&gt;&lt;/li&gt;&lt;li&gt;Giọng nói dễ nghe, truyền cảm và tự tin.\r\n&lt;/li&gt;&lt;li&gt;Khả năng giao tiếp tốt.\r\n&lt;/li&gt;&lt;li&gt;Có khả năng tổ chức và phối hợp công việc với mọi người trong team.\r\n&lt;/li&gt;&lt;li&gt;Có khả năng làm việc độc lập, làm việc nhóm.\r\n&lt;/li&gt;&lt;li&gt;Trung thực, có tinh thần trách nhiệm.&lt;/li&gt;&lt;/ul&gt;', 'VND:15000000-20000000', 0, '5 hours', None, '9d29f8be-90da-4d1f-b7bb-0f07f2cf0764', '16CE3974-1829-4D7F-9E60-76F1E3EC4EF9', 0, None),
#  ('03896805-3832-4efc-a353-d0ed7b3071a4', '&lt;p&gt;-Lương thỏa thuận\r\n&lt;/p&gt;&lt;p&gt;-Công việc ổn định\r\n&lt;/p&gt;&lt;p&gt;-Thưởng lễ, tết, lương tháng 13\r\n&lt;/p&gt;&lt;p&gt;-Các chế độ bảo hiểm theo luật lao động Việt Nam\r\n&lt;/p&gt;&lt;p&gt;-Được ký hợp đồng và nghỉ lễ Tết theo luật định\r\n&lt;/p&gt;&lt;p&gt;Môi trường làm việc năng động, hòa nhã và thân thiện&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 41, 1), datetime.datetime(2024, 4, 12, 0, 0), '&lt;p&gt;-Thiết lập các báo cáo thuế GTGT , TNCN tháng, quý, Quyết toán thuế TNDN, BCTC, thống kê, sổ sách,... theo qui định của Nhà nước và Điều lệ Công ty đầy đủ và đúng thời hạn.\r\n&lt;/p&gt;&lt;p&gt;-Lập bảng lương, bảo hiểm, HĐLĐ, công đoàn\r\n&lt;/p&gt;&lt;p&gt;-Biết về khai báo hải quan hàng xuất, nhập khẩu (sẽ được đào tạo thêm khi làm việc)\r\n&lt;/p&gt;&lt;p&gt;-Đảm bảo tính hợp pháp, tính kịp thời và tính chuẩn xác trong việc lập sổ sách tài liệu kế toán\r\n&lt;/p&gt;&lt;p&gt;-Hướng dẫn thi hành kịp thời các chế độ, qui định về tài chính, kế toán do Nhà nước ban hành cho các cấp thừa hành.\r\n&lt;/p&gt;&lt;p&gt;-Tổ chức bảo quản, lưu trữ các tài liệu kế toán, bảo mật các tài liệu và số liệu kế toán của công ty.\r\n&lt;/p&gt;&lt;p&gt;-Chịu trách nhiệm các số liệu liên quan đến thuế \r\n&lt;/p&gt;&lt;p&gt;-Chịu trách nhiệm trước GĐ về các công việc thuộc phạm vi trách nhiệm và quyền hạn của Kế toán trưởng\r\n&lt;/p&gt;&lt;p&gt;-Tuân thủ các quy định trong quá trình thực hiện công việc tại công ty.\r\n&lt;/p&gt;&lt;p&gt;-Chi tiết công việc sẽ được trao đổi cụ thể hơn trong buổi phỏng vấn.&lt;/p&gt;', 3, True, 'CONTRACT', 'https://www.topcv.vn/viec-lam/ke-toan-truong/1091460.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-tnhh-thiet-bi-new-diamond-4dded4ac8ca2806d11a4c70eb93e59f2-64d449ff85002.jpg', 'Kế Toán Trưởng', 10, '&lt;p&gt;-Tuổi: 30 – 40t\r\n&lt;/p&gt;&lt;p&gt;-Trình độ: Cao đẳng, đại học chuyên ngành kế toán \r\n&lt;/p&gt;&lt;p&gt;-Có kinh nghiệm quyết toán với cơ quan thuế trên 5 lần\r\n&lt;/p&gt;&lt;p&gt;-Sử dụng thành thạo Word, Excel, phần mềm kế toán MISA/...\r\n&lt;/p&gt;&lt;p&gt;-Có kiến thức vững và am hiểu nguyên tắc và chuẩn mực tài chính kế toán, nghiệp vụ thuế, hạch toán kế toán\r\n&lt;/p&gt;&lt;p&gt;-Năng động, trung thực, có tinh thần trách nhiệm, có khả năng làm việc độc lập \r\n&lt;/p&gt;&lt;p&gt;-Gắn bó lâu dài với công ty&lt;/p&gt;', 'VND:0-20000000', 0, '8 hours', None, 'ce4e0819-0215-4ee6-96a1-f7dcf651af57', '0CABFB66-08D0-4875-B8D0-D354FAD825A6', 0, None),
#  ('040626ce-8bb5-4db2-b27b-9e8744750760', '&lt;p&gt;&lt;b&gt;- Mức lương: từ 7 - 20 triệu + Hoa hồng\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Được làm việc trong môi trường năng động, có điều kiện phát triển bản thân và cơ hội thăng tiến trong nghề nghiệp.\r\n&lt;/p&gt;&lt;p&gt;- Thời gian làm việc: 8h00 - 17h00 từ thứ 2 đến thứ 6 và 8h00 - 12h00 thứ 7.\r\n&lt;/p&gt;&lt;p&gt;&lt;b&gt;- Được xét tăng lương theo năng lực.\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Du lịch, team building 1 lần/năm.\r\n&lt;/p&gt;&lt;p&gt;- Được thưởng sinh nhật, thai sản, hiếu hỉ.. theo quy định của công ty.\r\n&lt;/p&gt;&lt;p&gt;- Thưởng lương tháng 13 theo năng lực cá nhân và tình hình của công ty.\r\n&lt;/p&gt;&lt;p&gt;- Các chế độ phúc lợi xã hội như: BHYT, BHXH.. theo quy định của Nhà nước.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 45, 25), datetime.datetime(2024, 4, 4, 0, 0), '&lt;p&gt;- Gọi điện chăm sóc KH cũ và tư vấn KH mới về các sản phẩm in ấn và quà tặng\r\n&lt;/p&gt;&lt;p&gt;- Giải đáp các thắc mắc của khách hàng về sản phẩm qua gọi điện, chat, mail,...\r\n&lt;/p&gt;&lt;p&gt;- Làm việc trực tiếp với khách hàng, ghi nhận thông tin và báo cáo nội dung cho trưởng phòng.\r\n&lt;/p&gt;&lt;p&gt;- Thực hiện các vấn đề liên quan như trao đổi với khách hàng, kí kết và thực hiện hợp đồng.\r\n&lt;/p&gt;&lt;p&gt;- Theo dõi quá trình thanh lý hợp đồng, công nợ, và các công việc chăm sóc khách hàng trước, trong và sau hợp đồng.\r\n&lt;/p&gt;&lt;p&gt;- Công việc cụ thể trao đổi thêm khi phỏng vấn.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 4, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-sales-b2b-luong-cung-len-den-20tr-thang-hh/1250638.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/Iidgb7Vk47cQLhBPc4pZijJeGouTeHtg_1685930163____ffae01671d3efadab940a597e0f2a22f.jpeg', 'Nhân Viên Kinh Doanh - Sales B2B - Lương Cứng Lên Đến 20Tr/Tháng + HH', 7, '&lt;p&gt;- Trình độ: Tốt nghiệp Cao Đẳng trở lên\r\n&lt;/p&gt;&lt;p&gt;&lt;b&gt;- Có kinh nghiệm sale đối tượng khách hàng doanh nghiệp, B2B,&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Tuyển NỮ - tuổi từ 22 trở lên&lt;/p&gt;&lt;p&gt;- Ưu tiên các bạn có kinh nghiệm vị trí Telesales, Sales\r\n&lt;/p&gt;&lt;p&gt;- Tính tình cởi mở, hòa đồng, nhanh nhẹn\r\n&lt;/p&gt;&lt;p&gt;- Chủ động trong công việc, hỗ trợ đồng nghiệp và có ý thức tốt trong việc chăm sóc khách hàng.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 'VND:0-20000000', 0, '5 hours', None, '35a999ee-00b5-4bc5-b128-3f0dbd74e249', 'A4C6D986-F601-47C7-913B-9EFF6AABD9D8', 0, None),
#  ('04108521-9865-43b8-b29e-ef834d0c749f', '&lt;p&gt;● Hưởng thu nhập hấp dẫn&lt;/p&gt;&lt;p&gt;● Data sẵn, chuẩn bị sẵn thiết bị làm việc ( đồng phục, laptop, sổ kế hoạch...)&lt;/p&gt;&lt;p&gt;● Review lương hằng năm và hưởng tháng lương thứ 13&lt;/p&gt;&lt;p&gt;● Tham gia chương trình đào tạo bài bản từ các chuyên gia cấp cao&lt;/p&gt;&lt;p&gt;● Lộ trình thăng tiến rõ ràng trong công việc&lt;/p&gt;&lt;p&gt;● Phát triển bản thân trong môi trường tôn trọng bản sắc cá nhân&lt;/p&gt;&lt;p&gt;● Làm việc trong môi trường quốc tế, chuyên nghiệp, hiện đại&lt;/p&gt;&lt;p&gt;● Nhận học bổng Tiếng Anh toàn phần cho con cái và 50% học bổng cho người thân.&lt;/p&gt;&lt;p&gt;● Hoạt động Company Trip sôi nổi thường niên&lt;/p&gt;&lt;p&gt;● Hưởng chế độ nghỉ phép từ 14 ngày trở lên theo cấp bậc, nghỉ ngày lễ Giáng sinh hưởng full lương&lt;/p&gt;&lt;p&gt;● Được cấp toàn bộ thiết bị làm việc&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 41, 33), datetime.datetime(2024, 4, 13, 0, 0), '&lt;p&gt;&lt;strong&gt;Năm mới - Bước tiến mới, hãy sẵn sàng chinh phục thành công với vị trí Chuyên Viên Tư Vấn tại Apollo.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;Cơ hội tuyệt vời để gia nhập Tổ chức giáo dục và đào tạo 100% vốn nước ngoài đầu tiên tại Việt Nam, đang phát triển nhanh chóng và đầy tham vọng.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;Bạn sẽ có nhiều cơ hội gặp gỡ và thuyết phục khách hàng, xây dựng hành trình học tập độc đáo. Được đào tạo, làm việc linh hoạt, và có cơ hội phát triển sự nghiệp trong môi trường quốc tế đa dạng.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;MÔ TẢ CÔNG VIỆC:&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Chuyên viên Tư vấn Tuyển sinh - Người đại diện và là cầu nối của Apollo English với phụ huynh. Ở Apollo, bạn không chỉ là những người tư vấn, mà còn là nguồn động viên, giúp học viên và khách hàng lựa chọn hành trình học tập Tiếng Anh đúng đắn và đầy ý nghĩa.&lt;/p&gt;&lt;p&gt;&lt;strong&gt;Các công việc cụ thể&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;1. Tư vấn các khóa học tiếng Anh&lt;/p&gt;&lt;ul&gt;&lt;li&gt;Liên hệ điện thoại với các khách hàng tiềm năng thông qua data có sẵn để giới thiệu khóa học Tiếng Anh, tìm hiểu nhu cầu của khách hàng và thuyết phục khách hàng lên trung tâm để trải nghiệm buổi học thử.&lt;/li&gt;&lt;li&gt;Lên lịch các bài kiểm tra xếp lớp và tư vấn khóa học phù hợp cho học viên.&lt;/li&gt;&lt;li&gt;Đăng ký lớp học cho học viên, sắp xếp lớp cho học viên và làm thủ tục các khoản thanh toán khóa học&lt;/li&gt;&lt;li&gt;Bàn giao tiền mặt và hóa đơn, chứng từ thanh toán cho thủ quỹ/phòng kế toán&lt;/li&gt;&lt;li&gt;Chịu trách nhiệm về doanh số bán hàng của cá nhân và đội nhóm&lt;/li&gt;&lt;/ul&gt;&lt;p&gt;2. Các công việc khác theo sự phân công của Giám đốc Trung tâm&lt;/p&gt;', 5, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/chuyen-vien-kinh-doanh-tu-van-khoa-hoc-telesales-thu-nhap-khong-gioi-han-toi-15-20-trieu-go-vap-binh-tan-quan-7-bien-hoa-di-an/1244421.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/to-chuc-giao-duc-va-dao-tao-apollo-viet-nam-5dd4bce9c2fa0.jpg', 'Chuyên Viên Kinh Doanh /Tư Vấn Khóa Học/Telesales (Thu Nhập Không Giới Hạn Tới 15-20 Triệu) - Gò Vấp, Bình Tân, Quận 7, Biên Hòa, Dĩ An', 4, '&lt;p&gt;● Nam hoặc nữ tuổi từ 21 – 30 tuổi.&lt;/p&gt;&lt;p&gt;● Giao tiếp tốt và có khả năng tư vấn khách hàng qua điện thoại và trực tiếp.&lt;/p&gt;&lt;p&gt;● Có kinh nghiệm liên quan đến tư vấn, chăm sóc khách hàng là lợi thế.&lt;/p&gt;&lt;p&gt;● Khả năng làm việc độc lập và đội nhóm tốt.&lt;/p&gt;&lt;p&gt;● Có thể làm theo ca, cuối tuần và sẽ được nghỉ trong tuần.&lt;/p&gt;&lt;p&gt;● Giao tiếp Tiếng Anh khá là một lợi thế.&lt;/p&gt;', 'VND:0-20000000', 0, '7 hours', None, '72673d84-48f5-42b9-9781-79fe03ba79a6', 'BC6595AB-6B2E-4BB8-A7B2-78BE6C5FDDD6', 0, None),
#  ('044123b2-fff2-4cbc-ae05-7eec7efdca3b', '&lt;p&gt;&lt;b&gt;- Lương cơ bản: 6.000.000 - 8.000.000 + Thưởng doanh thu + Hoa hồng&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;- Tổng thu nhập từ 10.000.000vnđ đến hơn 25.000.000vnđ/tháng theo năng lực&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Môi trường làm việc năng động, chuyên nghiệp, luôn nhận được sự hỗ trợ từ đội ngũ quản lý kinh nghiệm, tận tâm&lt;/p&gt;&lt;p&gt;- Hỗ trợ data khách hàng cho nhân viên từ Hệ thống Marketing của công ty&lt;/p&gt;&lt;p&gt;- Được cấp phát đồng phục 1 lần/năm (áo, huy hiệu,...)&lt;/p&gt;&lt;p&gt;- Nhân viên và người thân được mua sản phẩm của công ty với mức giá ưu đãi&lt;/p&gt;&lt;p&gt;- Được tham gia các chuyến du lịch hằng năm với công ty ở trong và ngoài nước (trung bình 2-3 lần/năm)&lt;/p&gt;&lt;p&gt;- Được tham gia các khoá Đào tạo định kì của công ty.&lt;/p&gt;&lt;p&gt;- Được hưởng các chế độ bảo hiểm theo quy định của nhà nước.&lt;/p&gt;&lt;p&gt;- Tham gia các chuyến tình nguyện của công ty ở các mái ấm tình thương.&lt;/p&gt;&lt;p&gt;- Cơ hội thăng tiến, thuyên chuyển qua nhiều vị trí khác phù hợp với năng lực&lt;/p&gt;&lt;p&gt;- Phỏng vấn ngay, đi làm liền tay&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 43, 25), datetime.datetime(2024, 3, 31, 0, 0), '&lt;p&gt;- Tiếp nhận xử lý thông tin khách hàng, data tiềm năng từ Công ty\xa0&lt;/p&gt;&lt;p&gt;- Chăm sóc, kết nối khách hàng khi cần hỗ trợ về sản phẩm, dịch vụ Công ty cung cấp&lt;/p&gt;&lt;p&gt;- Cập nhật chương trình, chính sách ưu đãi cho khách hàng hiện hữu và tiềm năng&lt;/p&gt;&lt;p&gt;- Xử lý các tình huống phát sinh: báo giá, khiếu nại thắc mắc từ khách hàng&lt;/p&gt;&lt;p&gt;- Chưa có kinh nghiệm sẽ được đào tạo&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 1, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-cham-soc-khach-hang-telesale-tu-van-san-pham-co-dao-tao-di-lam-ngay-thu-nhap-12-trieu/1165365.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/e98511e31c4a2b8335d8882663468c09-6539dde403442.jpg', 'Nhân Viên Chăm Sóc Khách Hàng / Telesale/ Tư Vấn Sản Phẩm (Có Đào Tạo, Đi Làm Ngay) - Thu Nhập 12 Triệu', 2, '&lt;p&gt;&lt;b&gt;- Không có kinh nghiệm sẽ được đào tạo&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Siêng năng, chịu khó, có tinh thần trách nhiệm trong công việc.&lt;br /&gt;&lt;/p&gt;&lt;p&gt;- Giao tiếp khá, nhanh nhẹn, năng động, ham học hỏi, tác phong lịch sự, chuyên nghiệp&lt;/p&gt;&lt;p&gt;- Biết sử dụng cơ bản tin học văn phòng cơ bản\r\n&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 'VND:8000000-20000000', 0, '6 hours', None, '7b86bfaf-c0dc-4823-bb62-109ec5c73e83', 'B7EAFE07-2E2A-423B-92A3-3C90B4B0CB1D', 0, None),
# ...
#  ('fe772711-4ae2-4c40-b2f5-c775b9ba558e', '&lt;p&gt;&lt;b&gt;- Lương, thưởng hấp dẫn theo chế độ của công ty (Từ 12 triệu trở lên ++)\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Thưởng các ngày lễ lớn trong năm và ngày lễ của công ty.\r\n&lt;/p&gt;&lt;p&gt;- Đi du lịch hàng năm.\r\n&lt;/p&gt;&lt;p&gt;- Chế độ thai sản theo quy định của pháp luật.\r\n&lt;/p&gt;&lt;p&gt;- Chế độ phép năm.\r\n&lt;/p&gt;&lt;p&gt;- Thời gian làm việc: 8h/ ngày, nghỉ thứ 7 và chủ nhật.\r\n&lt;/p&gt;&lt;p&gt;- Được làm việc trong môi trường chuyên nghiệp, năng động và thân thiện.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 45, 52), datetime.datetime(2024, 4, 5, 0, 0), '&lt;p&gt;- Xây dựng kế hoạch kinh doanh, làm việc với khách hàng.&lt;/p&gt;&lt;p&gt;- Khai thác khách hàng qua các nền tảng thương mại điện tử như Alibaba; Amazon.&lt;/p&gt;&lt;p&gt;- Chăm sóc và quản lý dữ liệu khách hàng có sẵn của công ty.&lt;/p&gt;&lt;p&gt;- Được đào tạo kỹ năng thương mại điện tử, kỹ năng xuất nhập khẩu.&lt;/p&gt;', 3, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-phong-sales-xuat-nhap-khau/1039483.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-tnhh-xnk-pham-gia-5e6845809a9ff.jpg', 'Nhân Viên Phòng Sales Xuất Nhập Khẩu', 2, '&lt;p&gt;- Giới tính: Nữ&lt;/p&gt;&lt;p&gt;- Kỹ năng xây dựng phương án kinh doanh.&lt;/p&gt;&lt;p&gt;- Kỹ năng ra quyết định.&lt;/p&gt;&lt;p&gt;- Sử dụng phần mềm văn phòng thành thạo.&lt;/p&gt;&lt;p&gt;- Tiếng Anh giao tiếp cơ bản.&lt;/p&gt;&lt;p&gt;- Trung thực và tận tâm.&lt;/p&gt;&lt;p&gt;- Đam mê về kinh doanh, năng động, hướng ngoại &amp; dễ thích nghi.&lt;/p&gt;&lt;p&gt;- Chịu trách nhiệm, kiên định trong công việc và ham học hỏi&lt;br /&gt;&lt;/p&gt;', 'VND:0-12000000', 0, '6 hours', None, 'a9845148-e046-4a93-be1d-3678d946f5d5', '06FF8A9B-71F5-4CFC-A71F-72020484B955', 0, None),
#  ('fe8821dc-e5ce-43e1-92fa-dbbd11f2b2db', '&lt;p&gt;-\tMức thu nhập từ : 7.000,000 VNĐ đến 15.000.000 VNĐ tùy theo năng lực \r\n&lt;/p&gt;&lt;p&gt;-\t Lương tháng 13, thưởng cuối năm và nhận thưởng trong các dịp lễ tết trong năm\r\n&lt;/p&gt;&lt;p&gt;-\tĐược ký hợp đồng lao động và đóng BHYT, BHXH, BHTN theo quy định của pháp luật khi là nhân viên chính thức\r\n&lt;/p&gt;&lt;p&gt;-\tĐược đào tạo theo chương trình Đào tạo của công ty.\r\n&lt;/p&gt;&lt;p&gt;-\tMôi trường làm việc thoải mái, thân thiện...\r\n&lt;/p&gt;&lt;p&gt;-\tDu lịch công ty 1 lần/năm.\r\n&lt;/p&gt;&lt;p&gt;Tăng lương định kỳ theo năng lực và kết quả làm việc\r\n&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 43, 27), datetime.datetime(2024, 4, 4, 0, 0), '&lt;p&gt;-\tXây dựng và quản lý nội dung trên website, fanpage của công ty, kịch bản video, v.v. \r\n&lt;/p&gt;&lt;p&gt;-\tPhối hợp với designer và các thành viên trong team sản xuất nội dung chất lượng về chữ viết và hình ảnh\r\n&lt;/p&gt;&lt;p&gt;-\tChỉnh sửa, hiệu chỉnh, và tối ưu nội dung chuẩn SEO\r\n&lt;/p&gt;&lt;p&gt;-\tCập nhật xu hướng để đưa ra ý tưởng mới làm tăng tương tác và nhận diện thương hiệu.\r\n&lt;/p&gt;&lt;p&gt;-\tCó khả năng xây dựng và thể hiện câu chuyện, ý tưởng sáng tạo dựa trên phân tích insight và nhu cầu từng nhóm khách hàng, từ đó đề xuất các chiến thuật sáng tạo nội dung (PR, KOL, seeding...) nhằm đạt mục tiêu truyền thông của thương hiệu.\r\n&lt;/p&gt;&lt;p&gt;-\tNghiên cứu nhu cầu và xu hướng của khách hàng để phát triển chủ đề, nội dung mới phù hợp.\r\n&lt;/p&gt;&lt;p&gt;-\tCác công việc khác liên quan đến sáng tạo nội dung trên các kênh digital theo chỉ đạo của cấp trên.\r\n&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 4, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/senior-content-marketing/1250528.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/cong-ty-tnhh-luu-tru-so-62983ba8856ba.jpg', 'Senior Content Marketing', 8, '&lt;p&gt;-\tTốt nghiệp Cao đẳng, Đại học chuyên ngành Marketing, Truyền thông, hoặc các chuyên ngành liên quan. \r\n&lt;/p&gt;&lt;p&gt;-\tKinh nghiệm : ít nhất 2 năm kinh nghiệm ở vị trí tương đương\r\n&lt;/p&gt;&lt;p&gt;-\tCó kinh nghiệm quảng cáo Facebook, Google Adword và tư duy làm content marketing.\r\n&lt;/p&gt;&lt;p&gt;-\tBiết về Wordpress, tự dựng được landing page hoặc đã từng có kinh nghiệm làm việc với landing page.\r\n&lt;/p&gt;&lt;p&gt;-\tCó khả năng viết content tốt: Viết bài thông báo, nội dung quảng cáo facebook, nội dung website.\r\n&lt;/p&gt;&lt;p&gt;-\tYêu thích công việc sáng tạo nội dung và cung cấp giá trị cho khách hàng.\r\n&lt;/p&gt;&lt;p&gt;-\tBiết sử dụng các công cụ thiết kế cơ bản như Photoshop, Illustrator, v.v. là một lợi thế. \r\n&lt;/p&gt;&lt;p&gt;-\tAm hiểu về SEO và tối ưu nội dung trên website.\r\n&lt;/p&gt;&lt;p&gt;-\tThái độ làm việc nghiêm túc, trách nhiệm, nhiệt huyết, chăm chỉ.\r\n&lt;/p&gt;&lt;p&gt;-\tChủ động, trung thực trong công việc.\r\n&lt;/p&gt;&lt;p&gt;-\tÝ thức tự giác, kỹ năng làm việc độc lập, làm việc nhóm.\r\n&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 'VND:0-15000000', 0, '8 hours', None, '6c751a03-2b79-436e-b716-57f4235b5edd', 'CB7A08F1-724E-4EC5-82C5-BE92A77CEBB9', 0, None),
#  ('feacde81-da88-45e4-8379-c8867ef47a45', '&lt;p&gt;&lt;b&gt;- Lương cứng: 8 - 11 Triệu/tháng\xa0&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Đóng bảo hiểm, party hàng tháng, company trip trong năm.\r\n&lt;/p&gt;&lt;p&gt;- Ngày phép theo Luật Nhà nước.\r\n&lt;/p&gt;&lt;p&gt;- Môi trường làm việc thân thiện, trẻ, năng động, chuyên nghiệp, cơ hội thăng tiến rõ ràng.\r\n&lt;/p&gt;&lt;p&gt;- Được công ty đào tạo chuyên môn trong quá trình làm việc.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 40, 52), datetime.datetime(2024, 4, 15, 0, 0), '&lt;p&gt;- Thiết kế các ấn phẩm (flyer, brochure, voucher, poster,...)\r\n&lt;/p&gt;&lt;p&gt;- Thiết kế các vật phẩm POSM (backdrop, giấy mời, standee, bảng biển,...)\r\n&lt;/p&gt;&lt;p&gt;- Thiết kế, chỉnh sửa hình ảnh quảng cáo, truyền thông online marketing như banner, landing page, facebook, youtube,...\r\n&lt;/p&gt;&lt;p&gt;- Sử dụng tương đối thành thạo các phần mềm Photoshop, illustrator, lightroom.\r\n&lt;/p&gt;&lt;p&gt;- Phối hợp với bộ phận liên quan thực hiện các ý tưởng thiết kế.&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 2, True, 'FULL_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-graphic-designer/1257600.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/Q8BhpfTVw1BDMzz4eq7dYFmlck3b63ID_1649843104____c82ca17809ad97318dd1cec538e8dba3.jpg', 'Nhân Viên Graphic Designer', 2, '&lt;p&gt;- Tốt nghiệp chuyên nghành đồ hoạ, hoặc chương trình tương đương\r\n&lt;/p&gt;&lt;p&gt;- Đam mê đối với công việc thiết kế\r\n&lt;/p&gt;&lt;p&gt;- Ưu tiên các bạn có kinh nghiệm về lĩnh vực thiết kế&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 'VND:8000000-11000000', 0, '8 hours', None, 'cc633ed7-8b15-4bed-92ff-e7b44878ab60', '407072D0-85C3-415D-A1A7-C6E321725E89', 0, None),
#  ('fec8dcc2-084b-4465-94ca-a3b2080e2d46', '&lt;p&gt;- Mức lương hấp dẫn dựa trên năng lực và kinh nghiệm\r\n&lt;/p&gt;&lt;p&gt;- Phụ cấp khác: Lương tháng 13 &amp; thưởng hấp dẫn theo kết quả doanh thu của Công ty.\r\n&lt;/p&gt;&lt;p&gt;- Có chế độ công tác phí khi đi công tác xa.\r\n&lt;/p&gt;&lt;p&gt;- Được hưởng các chế độ BHXH, BHYT, BHTN, khám sức khỏe theo quy định.\r\n&lt;/p&gt;&lt;p&gt;- Được đi du lịch, nghỉ phép năm (12 ngày), nghỉ lễ theo quy định của Luật lao động hiện hành và theo quy định của Công ty.\r\n&lt;/p&gt;&lt;p&gt;- Được làm việc trong môi trường năng động, hiện đại, trong và ngoài nước.\r\n&lt;/p&gt;&lt;p&gt;- Đào tạo, bồi dưỡng &amp; phát triển nghề nghiệp: tham gia các khóa huấn luyện kỹ năng mềm hoặc chuyên môn theo nhu cầu của công ty.\r\n&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 41, 52), datetime.datetime(2024, 3, 29, 0, 0), '&lt;p&gt;- Quản lý dự án cơ điện\r\n&lt;/p&gt;&lt;p&gt;- Quản lý thiết kế, dự toán dự án\r\n&lt;/p&gt;&lt;p&gt;- Giám sát kỹ thuật, tính khối lượng thi công, tính toán vật tư thiết bị, kiểm soát tiến độ thi công.\r\n&lt;/p&gt;&lt;p&gt;- Triển khai bản vẽ thi công, bản vẽ biện pháp thi công, tính toán khối lượng, lập kế hoạch vật tư thiết bị, lập tiến độ thi công.\r\n&lt;/p&gt;&lt;p&gt;- Hồ sơ hoàn công.\r\n&lt;/p&gt;&lt;p&gt;- Trực tiếp tham gia thi công các dự án hoặc triển khai bản vẽ và hồ sơ tại Văn Phòng Hà Nội.\r\n&lt;/p&gt;&lt;p&gt;- Lập dự toán và hồ sơ thầu\r\n&lt;/p&gt;&lt;p&gt;- Thiết kế MEP&lt;/p&gt;', 1, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/ki-su-co-dien/959440.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/J8mG7164qyXhf89t4gf3QH9pOG2kmn97_1678699744____bd5cc74c3f6e96db6afdc9b0b5ca500f.jpg', 'Kĩ Sư Cơ Điện', 9, '&lt;p&gt;- Tốt nghiệp Đại học , Cao đẳng chuyên ngành (Điện, điện nhẹ...,Cấp thoát nước, Hệ thống kỹ thuật trong công trình, HVAC, PCCC....)\r\n&lt;/p&gt;&lt;p&gt;- Thành thạo vi tính, sử dụng tốt các phần mềm chuyên ngành (Autocad, Microsoft Project, các phần mềm văn phòng Word, Excel, Powerpoint... và các phần mền tính toán khác...)\r\n&lt;/p&gt;&lt;p&gt;- Có khả năng làm việc độc lập và theo nhóm\r\n&lt;/p&gt;&lt;p&gt;- Năng động sáng tạo, có khả năng sắp xếp công việc tốt.\r\n&lt;/p&gt;&lt;p&gt;- Cẩn thận, trung thực, nhanh nhẹn, chăm chỉ, nhiệt tình\r\n&lt;/p&gt;&lt;p&gt;- Sức khỏe tốt, chịu được áp lực.\r\n&lt;/p&gt;&lt;p&gt;- Chịu khó, nhiệt tình trong công việc, sẵn sàng tiếp thu cái mới\r\n&lt;/p&gt;&lt;p&gt;- Ưu tiên có kinh nghiệm cho các dự án có yếu tố nước ngoài\r\n&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;', 'VND:0-20000000', 0, '5 hours', None, 'afe074e5-31a2-490a-89c4-a93f7dd8065f', 'D5846B71-9143-4458-8DCE-1FFCD49AB3C2', 0, None),
#  ('ff15f4b1-d843-468b-a048-e394ec1c1cac', '&lt;ul&gt;&lt;li&gt;Thu nhập từ 7.000.000đ - 9.000.000/tháng&lt;/li&gt;&lt;li&gt;Trà chiều miễn phí&lt;/li&gt;&lt;li&gt;Môi trường làm việc thoải mái, đồng nghiệp hòa đồng.&lt;/li&gt;&lt;li&gt;BHXH theo quy định của nhà nước&lt;/li&gt;&lt;li&gt;Nghỉ Lễ, Tết theo quy định&lt;/li&gt;&lt;/ul&gt;&lt;p&gt;Thời gian làm việc: 8h- 17h30 (nghỉ trưa 1,5 tiếng) từ thứ 2 đến thứ 7&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 44, 4), datetime.datetime(2024, 5, 31, 0, 0), '&lt;ul&gt;&lt;li&gt;Đóng hàng (hàng gia dụng như máy rửa xe, thang, ghế xếp)&lt;/li&gt;&lt;li&gt;Hỗ trợ kho các công việc khác (nếu có)&lt;/li&gt;&lt;li&gt;Test sản phẩm trước khi đóng hàng gửi cho khách.&lt;/li&gt;&lt;/ul&gt;', 1, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-kho-hoang-mai-ha-noi/929663.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/ALODb34WcQrCO2E7UHSiBCRY9RF6Qa3O_1649134815____a81d62a25b970f73cd939a8ff9f85bf0.jpg', 'Nhân Viên Kho - Hoàng Mai, Hà Nội', 5, '&lt;ul&gt;&lt;li&gt;Không có kinh nghiệm được đào tạo.&lt;/li&gt;&lt;li&gt;Nhanh nhẹn, chăm chỉ, nhiệt tình, gắn bó lâu dài.&lt;/li&gt;&lt;li&gt;Có thể đi làm ngay.&lt;/li&gt;&lt;/ul&gt;', 'VND:7000000-9000000', 0, '7 hours', None, '2c5a340a-54b6-4cc4-8371-21e2a4beba3c', '6B93F6DB-9C48-4F02-84A6-82A2F2CB3692', 0, None),
#  ('ff9eaf51-b0d4-43c1-a11e-cde8c7e0e551', '&lt;p&gt;- Mức lương: 9-15 triệu/tháng (ứng viên có thể thỏa thuận và đề xuất theo năng lực)&lt;/p&gt;&lt;p&gt;- Hỗ trợ nghỉ 4 ngày, được nghỉ lễ theo quy định, được kí hợp đồng dài hạn theo quy định&lt;/p&gt;&lt;p&gt;- Được hưởng các chế độ BHYT, BHXH, ...theo Luật Lao động và các chế độ đãi ngộ, phúc lợi theo quy định của Công ty.&lt;/p&gt;&lt;p&gt;- Làm việc trong môi trường năng động chuyên nghiệp.&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 45, 50), datetime.datetime(2024, 4, 11, 0, 0), '&lt;p&gt;- Nhận biết các lỗi cơ bản về phần cứng của máy tính .\r\n&lt;/p&gt;&lt;p&gt;- Thành thạo công việc lắp ráp máy tính, nâng cấp linh kiện&lt;/p&gt;&lt;p&gt;- Cài đặt phần mềm, lắp đặt phần cứng, test máy, bảo hành, bán hàng\r\n&lt;/p&gt;&lt;p&gt;- Công việc trao đổi khi phỏng vấn&lt;/p&gt;&lt;p&gt;\r\n&lt;/p&gt;', 3, True, 'CONTRACT', 'https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-may-tinh-thu-nhap-len-den-15-trieu/1259407.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/54ee19b30e5ce874df8c4befdef1fcc0-65e54c2b4a461.jpg', 'Nhân Viên Kỹ Thuật Máy Tính (Thu Nhập Lên Đến 15 Triệu)', 8, '&lt;p&gt;- &lt;b&gt;Có kinh nghiệm cài đặt phần mềm tháo lắp máy&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Giao tiếp tốt&lt;/p&gt;&lt;p&gt;-Đã có kinh nghiệm đi làm&lt;/p&gt;&lt;p&gt;-Giao tiếp tốt với khách hàng&lt;/p&gt;&lt;p&gt;- Nam tuổi từ 21 -28&lt;/p&gt;&lt;p&gt;- Nhanh nhẹn, chịu khó, nhiệt huyết với công việc, gắn bó lâu dài với công ty.&lt;/p&gt;', 'VND:9000000-15000000', 0, '5 hours', None, '9309f81a-d576-4069-b5f0-6b0b5ce4ce86', '5FBAB3EC-4A63-43C0-BB7F-0489F178DD21', 0, None),
#  ('fff4fd9c-4c64-471e-9b0c-c58b3753f4b5', '&lt;p&gt;&lt;b&gt;- Không phải tìm kiếm khách hàng, không áp doanh số, làm việc tại văn phòng, không đi lại, không yêu cầu kinh nghiệm.\r\n&lt;/b&gt;&lt;/p&gt;&lt;p&gt;&lt;b&gt;- Lương: 10 - 15 tr + phụ cấp ăn ca + thưởng doanh số&lt;/b&gt;&lt;/p&gt;&lt;p&gt;- Công ty cung cấp điện thoại, máy tính làm việc.\r\n&lt;/p&gt;&lt;p&gt;- Được làm việc trong môi trường trẻ trung, năng động, được đào tạo và có cơ hội lên trưởng nhóm sau 4-6 tháng.\r\n&lt;/p&gt;&lt;p&gt;- Hưởng đầy đủ các chế độ theo quy định nhà nước: bảo hiểm, thưởng lễ tết, liên hoan hàng tháng, du lịch hàng năm...&lt;/p&gt;&lt;p&gt;- Có cơ hội học tập, nâng cao trình độ, khuyến khích nhân viên tham gia bồi dưỡng nâng cao nghiệp vụ, có trợ cấp chi phí đào tạo.\r\n&lt;/p&gt;&lt;p&gt;- Du lịch với công ty 01 lần/năm.&lt;/p&gt;', datetime.datetime(2024, 3, 15, 23, 43, 31), datetime.datetime(2024, 4, 13, 0, 0), '&lt;p&gt;- Tiếp nhận các cuộc điện thoại, các câu hỏi trên trang web, zalo, facebook của công ty&lt;/p&gt;&lt;p&gt;-️ Tư vấn, giải đáp cho khách hàng những vấn đề khách hàng băn khoăn&lt;/p&gt;&lt;p&gt;- Đăng ký thông tin, đặt lịch cho khách có nhu cầu sử dụng dich vụ của phòng khám&lt;/p&gt;&lt;p&gt;- Làm việc xoay ca:&lt;/p&gt;&lt;p&gt;\xa0&lt;/p&gt;', 4, True, 'PART_TIME', 'https://www.topcv.vn/viec-lam/nhan-vien-tu-van-telesales-y-te-khong-ap-doanh-so-thu-nhap-10-15m-thang/202480.html?ta_source=BoxFeatureJob_LinkDetail', '5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố Hồ Chí Minh', 'https://cdn-new.topcv.vn/unsafe/200x/https://static.topcv.vn/company_logos/c3bdc859a308a9fa128c5bf8df6fd703-61c3f7d10f9fd.jpg', 'Nhân Viên Tư Vấn/Telesales Y Tế-Không Áp Doanh Số Thu Nhập 10 - 15M/Tháng', 4, '&lt;p&gt;- Chưa có kinh nghiệp sẽ được đào tạo, chấp nhận sinh viên mới ra trường, đang chờ bằng tốt nghiệp.&lt;/p&gt;&lt;p&gt;- Ứng viên tốt nghiệp trung cấp trở lên, ưu tiên chuyên ngành liên quan đến y dược.&lt;/p&gt;&lt;p&gt;- Có thể làm việc theo ca.&lt;/p&gt;&lt;p&gt;- Kỹ năng giao tiếp tốt, nói năng lưu loát, dễ nghe.&lt;/p&gt;&lt;p&gt;- Sử dụng vi tính văn phòng.&lt;/p&gt;&lt;p&gt;- Trung thực, nhiệt tình, năng động, thật thà và có trách nhiệm với công việc.&lt;/p&gt;', 'VND:10000000-15000000', 0, '6 hours', None, '797e6801-4e9a-4e19-971f-90fdf431819a', '170034D0-2822-4ECB-94F8-737087BD447E', 0, None)]

# %%
job_df.head()
# Out:
#                                  job_id  \
# 0  00249d9f-88ea-4b81-a0ca-1923a8a75fce
# 1  00526e4f-c995-4bc8-8d4c-527387dbc113
# 2  016d51fa-ca59-46f3-9dc1-3ca070026424
# 3  018e75b3-dc53-4022-b06b-6beb23198a1a
# 4  01a27fb6-f982-4b67-b0b6-c16a88b2eebb
#
#                                              benefit           created_at  \
# 0  &lt;p&gt;- Thu nhập: &lt;/p&gt;&lt;p&gt;- Giáo...  2024-03-15 23:45:36
# 1  &lt;ul&gt;&lt;li&gt;&lt;b&gt;Thu nhập hấp dẫn ...  2024-03-15 23:43:53
# 2  &lt;p&gt;- Môi trường làm việc dân chủ, hiện đ...  2024-03-15 23:41:26
# 3  &lt;p&gt;&lt;b&gt;- Mức lương: Lương cạnh tran...  2024-03-15 23:43:18
# 4  &lt;p&gt;- Lương khởi điểm: 10 - 12tr/tháng (t...  2024-03-15 23:44:53
#
#               deadline                                        description  \
# 0  2024-04-01 00:00:00  &lt;p&gt;- Giảng dạy ngữ pháp, kỹ năng đọc viế...
# 1  2024-03-31 00:00:00  &lt;ul&gt;&lt;li&gt;Tìm kiếm và tư vấn dịch vụ...
# 2  2024-03-20 00:00:00  &lt;p&gt;- Nắm bắt được xu hướng về content.\r...
# 3  2024-04-14 00:00:00  &lt;p&gt;- Lập hồ sơ thiết kế, triển khai hồ s...
# 4  2024-04-15 00:00:00  &lt;p&gt;- Biên soạn, tổng hợp tài liệu, xây d...
#
#    experience  is_active   job_type  \
# 0           2       True   CONTRACT
# 1           2       True  FULL_TIME
# 2           2      False   CONTRACT
# 3           2       True   CONTRACT
# 4           1       True  PART_TIME
#
#                                                 link  \
# 0  https://www.topcv.vn/viec-lam/giao-vien-tieng-...
# 1  https://www.topcv.vn/viec-lam/nhan-vien-kinh-d...
# 2  https://www.topcv.vn/viec-lam/tro-ly-tieng-tru...
# 3  https://www.topcv.vn/viec-lam/kien-truc-su-luo...
# 4  https://www.topcv.vn/viec-lam/giao-vien-toan-t...
#
#                                             location  ... quantity  \
# 0  5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố...  ...        8
# 1  5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố...  ...        2
# 2  5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố...  ...        9
# 3  5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố...  ...        3
# 4  5/4 Lê Văn Chí, Linh Trung, Thủ Đức, Thành phố...  ...        4
#
#                                          requirement           salary_range  \
# 0  &lt;p&gt;- Tốt nghiệp chuyên ngành sư phạm Anh...  VND:10000000-18000000
# 1  &lt;ul&gt;&lt;li&gt;Trình độ cao đẳng trở lên,...  VND:10000000-30000000
# 2  &lt;p&gt;- Ưu tiên sinh viên sắp và mới tốt ng...  VND:10000000-15000000
# 3  &lt;p&gt;&lt;b&gt;- Chỉ nhận Tốt nghiệp đại họ...         VND:0-15000000
# 4  &lt;p&gt;- Có chuyên môn vững, kinh nghiệm giả...         VND:0-12000000
#
#   status     time                  updated_at  \
# 0      0  5 hours                         NaN
# 1      0  6 hours                         NaN
# 2      0  7 hours  2024-03-20 00:00:06.176000
# 3      0  8 hours                         NaN
# 4      0  6 hours                         NaN
#
#                        employer_user_id                  position_position_id  \
# 0  e0f3045c-ae4f-40cf-83ba-d845f3c76364  2DF30267-DFC8-499D-8C43-FF8E436E8EF9
# 1  d5abbf18-9ac8-44dc-ba71-5a768d1f3887  EBC24826-7EF7-4540-86B3-7CCD11481E21
# 2  99b11b9f-7288-4111-aae0-7e2f407163f9  c5606085-3ee9-4e1c-9810-daedf514994a
# 3  c88d0cbe-0dd4-44d2-842a-c3497e081ead  235A69EE-10E0-40E7-B261-4EBA9B5A491E
# 4  b44b8cc4-e962-45c9-8442-77c86db2f2d2  CBB96933-92E2-407C-89C7-AABA9279B9ED
#
#   total_view user_id
# 0          0     NaN
# 1          0     NaN
# 2          0     NaN
# 3          0     NaN
# 4          0     NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Because of the dataset being so big, we are going to resample only 5000 random songs.

# %%
job_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                894 non-null    object
#  1   benefit               894 non-null    object
#  2   created_at            894 non-null    object
#  3   deadline              894 non-null    object
#  4   description           894 non-null    object
#  5   experience            894 non-null    int64
#  6   is_active             894 non-null    bool
#  7   job_type              894 non-null    object
#  8   link                  890 non-null    object
#  9   location              894 non-null    object
#  10  logo                  894 non-null    object
#  11  name                  894 non-null    object
#  12  quantity              894 non-null    int64
#  13  requirement           894 non-null    object
#  14  salary_range          894 non-null    object
#  15  status                894 non-null    int64
#  16  time                  894 non-null    object
#  17  updated_at            62 non-null     object
#  18  employer_user_id      894 non-null    object
#  19  position_position_id  894 non-null    object
#  20  total_view            894 non-null    int64
#  21  user_id               0 non-null      float64
# dtypes: bool(1), float64(1), int64(4), object(16)
# memory usage: 147.7+ KB

# %% [markdown]
# We can notice also the presence of `\n` in the text, so we are going to remove it.

# %%
job_df['name'] = job_df['name'].str.replace(r'\n', '')

# %% [markdown]
# After that, we use TF-IDF vectorizerthat calculates the TF-IDF score for each song lyric, word-by-word.
#
# Here, we pay particular attention to the arguments we can specify.

# %%
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
lyrics_matrix = tfidf.fit_transform(job_df['name'])

# %% [markdown]
# *How do we use this matrix for a recommendation?*
#
# We now need to calculate the similarity of one lyric to another. We are going to use **cosine similarity**.
#
# We want to calculate the cosine similarity of each item with every other item in the dataset. So we just pass the lyrics_matrix as argument.

# %%
cosine_similarities = cosine_similarity(lyrics_matrix)

# %% [markdown]
# Once we get the similarities, we'll store in a dictionary the names of the 50  most similar songs for each song in our dataset.

# %%
similarities = {}

# %%
for i in range(len(cosine_similarities)):
    # Now we'll sort each element in cosine_similarities and get the indexes of the songs. 
    similar_indices = cosine_similarities[i].argsort()[:-50:-1] 
    # After that, we'll store in similarities each name of the 50 most similar songs.
    # Except the first one that is the same song.
    similarities[job_df['name'].iloc[i]] = [(cosine_similarities[i][x], job_df['name'][x], job_df['position_position_id'][x]) for x in similar_indices][1:]

# %% [markdown]
# After that, all the magic happens. We can use that similarity scores to access the most similar items and give a recommendation.
#
# For that, we'll define our Content based recommender class.

# %%
class ContentBasedRecommender:
    def __init__(self, matrix):
        self.matrix_similar = matrix

    def _print_message(self, job, recom_job):
        rec_items = len(recom_job)
        
        print(f'The {rec_items} recommended job for {job} are:')
        for i in range(rec_items):
            print(f"Number {i+1}:")
            print(f"{recom_job[i][1]} by {recom_job[i][2]} with {round(recom_job[i][0], 3)} similarity score") 
            print("--------------------")
        
    def recommend(self, recommendation):
        # Get song to find recommendations for
        song = recommendation['song']
        # Get number of songs to recommend
        number_songs = recommendation['number_songs']
        # Get the number of songs most similars from matrix similarities
        recom_song = self.matrix_similar[song][:number_songs]
        # print each item
        self._print_message(job=song, recom_job=recom_song)

# %% [markdown]
# Now, instantiate class

# %%
recommedations = ContentBasedRecommender(similarities)

# %% [markdown]
# Then, we are ready to pick a song from the dataset and make a recommendation.

# %%
recommendation = {
    "song": job_df['name'].iloc[13],
    "number_songs": 10
}

# %%
recommendation
# Out:
# {'song': 'Kế Toán Trưởng', 'number_songs': 10}

# %%
recommedations.recommend(recommendation)
# Out:
# The 10 recommended job for Kế Toán Trưởng are:
# Number 1:
# Kế Toán Trưởng by 0CABFB66-08D0-4875-B8D0-D354FAD825A6 with 1.0 similarity score
# --------------------
# Number 2:
# Kế Toán Trưởng by 47947EC3-CD18-4FB6-81F9-833C7F375208 with 1.0 similarity score
# --------------------
# Number 3:
# Kế Toán Trưởng Thu Nhập Từ 20 - 30 Triệu by D5846B71-9143-4458-8DCE-1FFCD49AB3C2 with 0.697 similarity score
# --------------------
# Number 4:
# Chuyên Viên Kế Toán by 06FF8A9B-71F5-4CFC-A71F-72020484B955 with 0.678 similarity score
# --------------------
# Number 5:
# Kế Toán Bán Hàng by E93F133B-8B6F-45C1-9A32-C23D26676224 with 0.595 similarity score
# --------------------
# Number 6:
# Kế Toán Trưởng Thu Nhập Từ 18 -20 Triệu, Tại Hà Nội by 42FC988E-29A8-4DF2-A693-E9C8D5256502 with 0.593 similarity score
# --------------------
# Number 7:
# Kế Toán Trưởng - Lương Upto Đến 35 Triệu by 7459E7A6-FF41-4E2B-AA1A-8F0A52AF5F91 with 0.59 similarity score
# --------------------
# Number 8:
# Kế Toán Thuế by 5ECE813D-0D54-48A6-B32D-A76717028E48 with 0.554 similarity score
# --------------------
# Number 9:
# Kế Toán Trưởng ( Thu Nhập Từ 25 Triệu Đến 35 Triệu ) by 1F405075-CFC1-4136-8F66-798C48627D34 with 0.547 similarity score
# --------------------
# Number 10:
# Nhân Viên Kế Toán Nội Bộ by a50d7dc0-ffde-4315-9783-c8e902323549 with 0.535 similarity score
# --------------------
